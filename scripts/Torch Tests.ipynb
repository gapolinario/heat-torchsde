# %%
import torch as t
import matplotlib.pyplot as plt

# %%
N = 256
x = t.rand((N,))

# %%
plt.plot(x)
plt.plot(t.real(z))
plt.plot(t.real(z)-x)
plt.show()

# %%
y = t.fft.fft(x)

# %%
z = t.fft.ifft(y)

# %%
t.allclose(t.real(z),x)
# Out:
# False
